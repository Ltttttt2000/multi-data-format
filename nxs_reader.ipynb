# %%
import mne

path = 'D:\\NC-2023-HE-04\\柔性电极动物实验数据\\NC-2023-HE-04\\大鼠的神经信号采集\\柔性电极-64通道_神经信号_第50天E\\柔性电极-64通道_神经信号_第50天E.ns5'
# ns = mne.io.read_raw_nsx(path)
ns = mne.io.read_raw_nsx(path)
print(type(ns))
print('ns.ch_names:', ns.ch_names)
# print(ns.n_times)
print(ns)

# ns6: 125936401
# ns3: 8395760  2khz
# Out:
# Extracting NSX parameters from D:\NC-2023-HE-04\柔性电极动物实验数据\NC-2023-HE-04\大鼠的神经信号采集\柔性电极-64通道_神经信号_第50天E\柔性电极-64通道_神经信号_第50天E.ns5...
# Setting channel info structure...
# <class 'mne.io.nsx.nsx.RawNSX'>
# ns.ch_names: ['chan1', 'chan2', 'chan3', 'chan4', 'chan5', 'chan6', 'chan7', 'chan8', 'chan9', 'chan10', 'chan11', 'chan12', 'chan13', 'chan14', 'chan15', 'chan16', 'chan17', 'chan18', 'chan19', 'chan20', 'chan21', 'chan22', 'chan23', 'chan24', 'chan25', 'chan26', 'chan27', 'chan28', 'chan29', 'chan30', 'chan31', 'chan32']
# <RawNSX | 柔性电极-64通道_神经信号_第50天E.ns5, 32 x 3318047 (110.6 s), ~30 kB, data not loaded>

# %%
tmp = ns.to_data_frame()
print(tmp)
# Out:
#                time    chan1    chan2    chan3    chan4    chan5    chan6  \
# 0          0.000000  0.07350  0.08975  0.07550  0.10500  0.07800  0.07175
# 1          0.000033  0.10425  0.10800  0.11600  0.11950  0.12375  0.12125
# 2          0.000067  0.11925  0.11375  0.13650  0.11775  0.15500  0.16000
# 3          0.000100  0.09750  0.09250  0.11225  0.10775  0.12200  0.13875
# 4          0.000133  0.07200  0.08675  0.09050  0.10475  0.07850  0.09275
# ...             ...      ...      ...      ...      ...      ...      ...
# 5663469  188.782300 -0.73250 -0.66775 -0.69700 -0.67775 -0.75550 -0.70925
# 5663470  188.782333 -0.70775 -0.66475 -0.67075 -0.66550 -0.71075 -0.66150
# 5663471  188.782367 -0.72475 -0.68900 -0.69775 -0.69050 -0.72700 -0.67550
# 5663472  188.782400 -0.72700 -0.69050 -0.70550 -0.69275 -0.73000 -0.68675
# 5663473  188.782433 -0.71800 -0.68725 -0.68875 -0.68675 -0.72650 -0.68675
#
#            chan7    chan8    chan9  ...   chan23   chan24   chan25   chan26  \
# ...
